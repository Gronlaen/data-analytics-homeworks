# %% [markdown]
# ## Homework 2

# %% [markdown]
# ### 1.
# Obtain all the data for the Bachelor students, starting from 2007. Keep only the students for which you have an entry for both `Bachelor semestre 1` and `Bachelor semestre 6`. Compute how many months it took each student to go from the first to the sixth semester. Partition the data between male and female students, and compute the average -- is the difference in average statistically significant?

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

#ISA base url. This is the page that displays the form
isa_base_url = 'http://isa.epfl.ch/imoniteur_ISAP/!GEDPUBLICREPORTS.html'

#list of ID of academic periods, starting from 2007-2008
academic_periods = [978181, 978187, 978195, 39486325, 123455150, 123456101, 213637754, 213637922, 213638028, 355925344]

#list of ID of semesters (only for bachelor, starting at 1)
#semesters = [249108, 249114, 942155, 942163, 942120, 942175]
semesters = [249108, 942120, 942175]

params_dict = {'ww_x_GPS': -1,
               'ww_i_reportmodel': 133685247,
               #'ww_c_langue': None,
               'ww_i_reportModelXsl': 133685270,
               #'zz_x_UNITE_ACAD': 'Informatique',
               'ww_x_UNITE_ACAD': 249847,
               #'zz_x_PERIODE_ACAD': '2007-2008',
               'ww_x_PERIODE_ACAD': 978181,
               #'zz_x_PERIODE_PEDAGO': 'Bachelor+semestre+1',
               'ww_x_PERIODE_PEDAGO': 249108,
               #'zz_x_HIVERETE': None,
               'ww_x_HIVERETE': 'null',
               #'dummy': 'ok'
              }
data = {'Sciper': [], 'Civilite': [], 'Nom': [], 'BA1' : [],'BA5' : [],'BA6' : [],}
for current_year in academic_periods :
    params_dict['ww_x_PERIODE_ACAD'] = current_year
    for current_semester in semesters :
        params_dict['ww_x_PERIODE_PEDAGO'] = current_semester

        resp = requests.get(isa_base_url, params=params_dict)
        data_list = resp.text
        soup = BeautifulSoup(data_list, 'html.parser')
        table = soup.findAll('table')[0]
        rows = table.findAll('tr')[2:]
        year = table.findAll('tr')[0].findAll('th')[0].get_text()[14:23]
        bachelor_year = table.findAll('tr')[0].findAll('th')[0].get_text()[43]
        for row in rows:
            cols = row.findAll('td')
            data['Sciper'].append(int(cols[10].get_text()))
            data['Civilite'].append(cols[0].get_text())
            data['Nom'].append(cols[1].get_text())
            data['BA' + bachelor_year].append(year)
            if (bachelor_year is "1"):
                data['BA5'].append(None)    
                data['BA6'].append(None)
            elif (bachelor_year is "5"):
                data['BA1'].append(None)    
                data['BA6'].append(None)
            elif (bachelor_year is "6"):
                data['BA1'].append(None)    
                data['BA5'].append(None)
    
df = pd.DataFrame(data)
df.sort_values(['Sciper','Nom'], inplace=True)
df = df.set_index(['Sciper', 'Nom'])

df
# Out:
#                                                                 BA1  \
# Sciper Nom
# 147008 Good Xavier                                        2008-2009
#        Good Xavier                                             None
#        Good Xavier                                             None
# 153762 Conus Johann                                            None
#        Conus Johann                                            None
# 154157 Andriambololona Riana Miarantsoa                        None
# 159516 Raja Yanick                                             None
#        Raja Yanick                                             None
# 159998 Jesse Julia                                             None
#        Jesse Julia                                             None
# 160213 Bécholey Alexandre                                      None
# 161091 Grivet Ekaterina                                        None
# (161930, Lunang Pomkam Auguste Carmen)                0    2    2         4
# (165562, Lorch Daniel)                                0    1    1         2
# (166001, Di Maïo Vincent)                             0    1    0         1
# (166260, Mader Arnaud)                                0    1    1         2
# (166344, Blatter Jérémy)                              0    2    2         4
# (166548, Delort Vincent)                              0    1    1         2
# (166701, Beuret Thibaut)                              0    2    2         4
# (166746, Donzé Benjamin)                              0    1    1         2
# (166748, Dos Santos Patrick)                          0    1    1         2
# (166751, Droz Olivier)                                0    1    1         2
# (166889, Genet Henry)                                 0    1    1         2
# (167007, Ly Papa Alioune)                             0    3    3         6
# (167045, Tangui Achraf)                               0    1    1         2
# (167313, Marfurt Nicolas)                             0    1    1         2
# (167386, Nguyen-Xuan Jérémy)                          0    1    1         2
# (167439, Waldmeyer Marc)                              0    1    1         2
# (167447, Taggiasco Matthieu)                          0    1    0         1
# ...                                                 ...  ...  ...       ...
# (274740, Durussel Samad Emrys)                        1    0    0         1
# (274746, Beuret Florian)                              1    0    0         1
# (274748, Berla Francesco)                             1    0    0         1
# (274751, Bochatay Séverine)                           1    0    0         1
# (274839, Fatton Louise Olga)                          1    0    0         1
# (274900, Laraki Rayane)                               1    0    0         1
# (274902, Montial Charline)                            1    0    0         1
# (274918, Griesser Paul Roland Jacques)                1    0    0         1
# (274944, Gerber Frédéric Julien)                      1    0    0         1
# (274957, Giunta Julie Camille Rosalie)                1    0    0         1
# (274960, Golubev Maxim)                               1    0    0         1
# (274999, Iseli Lucien Michaël)                        1    0    0         1
# (275001, Idrizi Gonxhe)                               1    0    0         1
# (275071, Krcmar Peter)                                1    0    0         1
# (275102, Friedli Jonathan)                            1    0    0         1
# (275105, Fournier Julien Marcel)                      1    0    0         1
# (275116, Fusi Noah Duoc)                              1    0    0         1
# (275142, Luisier Gabriel Xavier)                      1    0    0         1
# (275159, Nejad Sattary Kamran Ali)                    1    0    0         1
# (275199, Ottaviani Lorenzo Antonio Maria)             1    0    0         1
# (275273, Servat Jean-Marc Patrick)                    1    0    0         1
# (275313, Dumoulin Paul Milan)                         1    0    0         1
# (275383, Cochard Victor Angel)                        1    0    0         1
# (275553, Hu Julien)                                   1    0    0         1
# (275608, Boujo Max)                                   1    0    0         1
# (276016, Wilders Eric Bruno John)                     1    0    0         1
# (276323, Zeller Corentin Luc Claude)                  1    0    0         1
# (276507, Thierry D'Argenlieu Nicolas Alain Alex...    1    0    0         1
# (276937, Chappuis Sébastien Max Roland)               1    0    0         1
# (277113, Geinoz Grégory)                              1    0    0         1
#
# [1465 rows x 4 columns]

# %%
frame = pd.DataFrame(columns=('Civility','Name','SCIPER'))
rows = table.findAll('tr')
for tr in rows[2:]:
    cols = tr.findAll('td')
    # currency row
    if (len(cols) is 12) :
        a, b, c, d, e, f, g, h, i, j, k, l = [c.text for c in cols]
        #print (a, b, k)
        newFrame = pd.DataFrame([a,b,k])
        frame.append(newFrame)
        #print(newFrame)
